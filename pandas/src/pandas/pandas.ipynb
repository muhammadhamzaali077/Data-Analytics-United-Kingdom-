# %%
import pandas 
import numpy as np

a = pandas.Series([1, 3, 5, 6, 8])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas
#       2 import numpy as np
# ----> 4 a = pandas.Series([1, 3, 5, 6, 8])
#
# AttributeError: module 'pandas' has no attribute 'Series'

# %% [markdown]
# # 1. Series
#     - single column
#     - 1D
# # 2. DataFrame
#     - Complete table
#     - multi dimensional

# %%
pd.dataframe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.dataframe()
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
print(pd.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(pd.__version__)
#
# AttributeError: module 'pandas' has no attribute '__version__'

# %%
a = pd.Series([1, 3, 5, 6, 8])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a = pd.Series([1, 3, 5, 6, 8])
#
# AttributeError: module 'pandas' has no attribute 'Series'
