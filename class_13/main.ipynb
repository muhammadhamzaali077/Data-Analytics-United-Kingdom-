# %% [markdown]
# # chapter 10
# # file handling

# %% [markdown]
# ### open(file_path, mode)
# ### mode
# - read (r) use for reading file only existing file
# - write (w) use for writing file, if doesn't exits creates a file, if exist overwrite the data
# - append (a) for appending at the end of existing file, if doesn't exits creates a file
# - exclusive (x) use creating new file if file exist raises error
# - read/write (r+) for read and write both if file exists
# - read/write (w+) use for writing and read file, if doesn't exits creates a file, if exist overwrite the data
# - binary (b) for reading writing binary files (rb, wb, ab)
# - text mode (t) default for text

# %%
file_data = open("data.txt", "r")
file_data.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 file_data = open("data.txt", "r")
#       2 file_data.read()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %%
try:
    file_data = open("data.txt", "r")
    print(file_data.read())
except FileNotFoundError:
    print("please create the file")
# Out:
# this file is for testing purpose
# this is line 2
# this is line 3
# this is line 4
# this is line 5
# this is line 6

# %%
try:
    file_data = open("data.txt", "r")
    print(file_data.readable()) # return True if you can read the file
    # print(file_data.read()) # read complete file
    # print(file_data.readline())
    # print(file_data.readline())
    # print(file_data.readline())
    # print(file_data.readline())
    # print(file_data.readline())
    # print(file_data.readline()) # read only single line
    # print(file_data.readlines()) # return list of lines
    for line in file_data.readlines():
        print("line number", line)
except FileNotFoundError:
    print("please create the file")
# Out:
# True
# line number this file is for testing purpose
#
# line number this is line 2
#
# line number this is line 3
#
# line number this is line 4
#
# line number this is line 5
#
# line number this is line 6

# %% [markdown]
# # cursor/ pointer
# - tell() return the position of cursor
# - seek() set manually position of cursor

# %%
try:
    file_data = open("data.txt", "r")
    print("starting location", file_data.tell())
    # print(file_data.read())
    print(file_data.readline())
    print("Ending location", file_data.tell())
except FileNotFoundError:
    print("please create the file")
# Out:
# starting location 0
# this file is for testing purpose
#
# Ending location 34

# %%
try:
    file_data = open("data.txt", "r")
    file_data.seek(8)
    print("starting location", file_data.tell())
    # print(file_data.read())
    print(file_data.readline())
    print("Ending location", file_data.tell())
except FileNotFoundError:
    print("please create the file")
# Out:
# starting location 8
# e is for testing purpose
#
# Ending location 34

# %%
try:
    file_data = open("data.txt", "w")
    print(file_data.tell())
    file_data.write("data replaced")
    print(file_data.tell())
    file_data.write(" for bank")
except FileNotFoundError:
    print("please create the file")
# Out:
# 0
# 13

# %%
try:
    file_data = open("data.txt", "r")
    print(file_data.read())
except FileNotFoundError:
    print("please create the file")
# Out:
# data replaced for bank

# %%
try:
    file_data = open("new.txt", "r+")   
    file_data.seek(72)
    file_data.write("this line is for askari bank")
except FileNotFoundError:
    print("please create the file")

# %%
try:
    file_data = open("new.txt", "r")
    print(file_data.read())
except FileNotFoundError:
    print("please create the file")
# Out:
# data replaced
# for bank
# new data
# added at 20
# bank
# this is line 6
# this line is for askari bank 8
# this is line 9
# this is line 10

# %%
import pprint
data = open("new.txt", "r")
lines = data.readlines()
# pprint.pprint(lines)

lines[6] = "this is the for askari bank\n"
pprint.pprint(lines)

# %%
file = open("new.txt", "w")
file.writelines(lines)
file.close()

# %%
file.tell()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 file.tell()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# ```python
# with open(file_path,mode) as file:
#     write
#     read
# ```

# %%
with open("new.txt", "r+") as data:
    print(data.read())
    print(data.tell()) # 149
    data.write("\nthis is line 11")
    print(data.tell())
    data.seek(0)
    print(data.read())

try:
    print(data.tell())
except ValueError:
    print("file closed")
# Out:
# data replaced
# for bank
# new data
# added at 20
# bank
# this is line 6
# this is the for askari bank
# this  is line 8
# this is line 9
# this is line 10
# 149
# 166
# data replaced
# for bank
# new data
# added at 20
# bank
# this is line 6
# this is the for askari bank
# this  is line 8
# this is line 9
# this is line 10
# this is line 11
# file closed

# %%
with open("abc.txt", "a+") as f:
    f.write("this mode is appending")
    f.write(" hello")
    f.seek(0)
    print(f.read())
    f.seek(5)
    f.write(" class 13")
# Out:
# this mode is appending hello

# %%
try:
    with open("data.txt", "x") as file:
        file.write("this is exclusive file")
        file.seek(0)
        print(file.read())
except FileExistsError:
    print("existing file can't be open in x mode")
# Out:
# existing file can't be open in x mode

# %%
try:
    with open("new_data.txt", "x+") as file:
        file.write("this is exclusive file")
        file.seek(0)
        print(file.read())
except FileExistsError:
    print("existing file can't be open in x mode")
# Out:
# existing file can't be open in x mode

# %%
with open("new_data.txt", "r") as file:
    content = file.read()
    print("original File", content)
    
    with open("copy.txt", "w") as writing_file:
        writing_file.write(content)
        
    with open("copy.txt", "r" ) as read_file:
        print("copied File", read_file.read())
# Out:
# original File this is the original new_data file
# copied File this is the original new_data file

# %%
def read_image(src_file, des_file):
    try:
        with open(src_file, "rb") as src_image:
            with open(des_file, "wb") as des_image:
                while True:
                    chunk = src_image.read(1024) #1kb
                    if not chunk:
                        break
                    des_image.write(chunk)
        print(f"image copied successfully from {src_file} to {des_file}")
    except FileNotFoundError:
        print("source file not found")
    except Exception as e:
        print(f"an error occurred {e}")
    
read_image("download.jpg", "copy_image.jpg")
read_image("copy_image.jpg", "abc.txt")
# Out:
# image copied successfully from download.jpg to copy_image.jpg
# image copied successfully from copy_image.jpg to abc.txt

# %%
with open("abc.txt", "rb") as file:
    print(file.read())
    with open("xyx.jpg", "wb") as des_image:
                while True:
                    chunk = file.read(1024) #1kb
                    if not chunk:
                        break
                    des_image.write(chunk)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x0f\x0f\x10\x10\x0f\x0f\x10\x10\x10\x15\x10\x0f\x12\x10\x10\x10\x16\x10\x10\x16\x10\x0f\x15\x15\x17\x16\x17\x15\x13\x15\x15\x18\x1c* \x18\x1f&\x1b\x15\x15!1!&*+./.\x17\x1f?83,7(..+\x01\n\n\n\x0e\r\x0e\x1a\x10\x10\x1a+%\x1f\x1f+/.+-------------+--------------------------+-----\xff\xc0\x00\x11\x08\x00\xa0\x01:\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x06\x01\x03\x04\x02\x07\x08\xff\xc4\x00L\x10\x00\x01\x03\x02\x03\x03\x07\x07\x07\x08\x07\t\x00\x00\x00\x00\x01\x00\x02\x03\x04\x11\x05\x12!\x061A\x07\x13"Qaq\x81\x142BR\x91\xa1\xb1\x15brs\x92\xc1\xd145ST\xa2\xb3\xd2\xd3\x17#$3\x82\xb2\xc3%6Dct\x83\xc2\xe1\xf0\xff\xc4\x00\x1b\x01\x01\x00\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\xff\xc4\x00,\x11\x01\x00\x02\x02\x01\x02\x04\x05\x04\x03\x01\x00\x00\x00\x00\x00\x00\x01\x02\x03\x11\x12\x041\x05!AQ\x13\x15"2a\x143Rq#\x81\x91B\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?_\x1a\xa6\xa4huD\xade\xfc\xd6\xea^\xee\xe6\x8dJ\xbd1\xda\xff\x00l)|\x95\xa7yUj\xb9L\xa7\x1aE\x04\xd2v\xb8\xb1\x80\xfb\xc9\xf7-\x88\xe8\xed\xeb-y\xea\xeb\xe9\x08\xf7\xf2\x9e\xfe\x14\x8d\xf1\x98\xff\x00\x02\xbct\x7f\x95?W\xf8\x19\xca\x83\xf8\xd27\xc2s\xfc\t=\x1f\xe51\xd5\xfe\x12\x14\x9c\xa6S8\x81,3E\x7fHe{G~\xe3\xeeX\xed\xd2[\xd2W\xafUY\xee\xb8\xd0W\xc3P\xc1,26F\x9d\xce\x07\x8fQ\xea=\x85kMf\xb3\xa9lV\xd1h\xdc:T,                                \xc3\x90|\x13\x18\xc4\x1fS<\xb3\xbc\x92^\xf2G\xcdm\xfa-\x1d\x80.\xce:\xc5k\x11\x0e>KM\xad3.\x12\xae\xa0\xa1,(K\xca\x81;\xb1\xd8\xd3\xe8\xea\xa3 \x9enG\xb69\x9b\xc0\x82l\x1d\xde/\x7fj\xc5\x9f\x1cZ\xac\xd8rq\xb4~_p\x0b\x96\xe9\x88\x08\x08\x08\x08\x08\x08\x08\x08<\x87\x82H\x04\\Z\xe2\xfa\x8b\xee\xba\n\xb6\xd9c\xb3\xd2\xcdE\x14%\xa0TKi\tm\xdd`\xf8\xc5\x85\xf4\x1a8\xf0Ak@@@@@@@@@@@@@@@@@@@@A\xe2_5\xdfD\xfc\x12;\xa2{?<\xb7r\xeeGg\x16{\xb0\x80T%\x85\tyA\xb2\x0f9\xbfI\xbf\x15[vZ\xbd\xdf\xa2\x02\xe3\xba\xec\xa0  \xe6\xae\xaf\x86\x9d\xb9\xe6\x91\x91\xb7\xad\xce\x02\xfd\x83\xad\x0436\xe3\x0c.\xca*[\xdeY(o\xda-\xb2\x0b\x03\x1e\x1c\x03\x9aC\x81\x17\x04\x10A\x07q\x05\x07-\x06+\x05C\xa4l26C\x11\x01\xf9nCI\xbd\x85\xf7\x1d\xc7r\r\xd5uL\x85\x8e\x96G\x061\x82\xeeq\xdc\x02\x0ec\x8dS\x08<\xa8\xca\xdeg\xf4\xba\xe5\xf3\xb2\xf5z\xda \xa1ry\x8d\xd3@j\xb9\xf9\x9a\xc3,\xac,\xcd{\xbf\xce\x17\xdd\xda\x10wr\x8d\xf9^\x17\xf5\xc7\xf7\x90\xa0\xb4Wm%\x0c\x0e\xc9-LMp\xde\xdb\xe6p\xef\r\xbd\xbcPw\xd1V\xc5;\x04\x90\xbd\xb24\xeesH#\xbb\xb0\xf6 \xd7\x89bpS7<\xf2\xb60M\x81\'W\x1e\xa0\x06\xa7\xc1\x04m\x06\xd8a\xf3\xbcG\x1dCs\x13`\x1c\xd7\xb31\xea\x05\xc0\x04\x13\xa8"1=\xa6\xa1\xa6%\xb3TF\xd7\r\xec\x17s\x87{Z\t\x083\x84\xed-\x15[\xb2A;\\\xeb_!\x0ek\x88\x1b\xec\x1c\x05\xfc\x10K            \xd5SP\xc8\x9a_#\x9a\xc6\xb4]\xceq\x01\xa3\xbc\x951\x133\xa8D\xccDnUz\xaePhXl\xdev[zM\x8e\xcd\xfd\xa2\x16\xc5zL\x93\xdf\xc9\xafn\xab\x1cvs\x9eQ\xe8\xce\x9c\xd5G\xd9\x8f\xf8\xd5\xbfG\x7fxW\xf5t\xf6W~R\xc0?R\xa8\xfbG\xf9\xab7\x0c\xff\x00\xc9\x87\x9e\x0fc\xe5<\x03\xf5*\x8f\xb4\x7f\x9a\x9c3\xff\x00$\xf3\xc3\xec\xc3\xb1,\x06\xc6\xd4U\x1b\xb4\xe9\x1f\xe6\xa8\xe1\x9f\xdc\xe7\x87\xd9K\x0bi\xac\xc2\r\x90y\xcd\xfaM\xf8\xaa\xdb\xb2k\xde\x1f|\xaa\xc4\x1b\x1b\xb2\xb88\xe9},\xbc\xbfU\xe28\xfa{\xf1\xb4K\xbd\x8b\x05\xaf\x1b\x86\x91\x8cG\xd4\xe1\xe0?\x15\xaf\x1e3\x82gZ\x96Y\xe8\xf2;\xe1\x99\xaf\x17i\xb8]<Y\xa9\x96\xbc\xa9;\x86\xb5\xab5\x9dKb\xca\xab\xe7\xb5 ...
